# %%
Task:Calculate a solution to the expression below. (6+4)x2/10. 
Answer: 6+4=10x2=20/10=2.0
Task: Create code such that x = 5 and y = x. Then let x = 7. Determine the value of y
Answer: x=5, y=x, x=7, y. Answer=5
Task: Generate a for loop that prints the square of each integer from 0 to 5 to the screen. Remember to use the ** symbols for calculating a power, and remember that the last value is not included.
Answer: for i in range (6):
print(i**2)
Code: 0 1 4 9 16 24
Task: Initialize the variable i by assigning it the value 0. This overwrites the current value stored in i as used above. Print the square of each 1 -unit increment in i, while i remains less than 10.
Answer: i=0 
while i<10:
 print(i**2)
i=i+1
code : 0 1 4 9 16 25 36 49 64 81
